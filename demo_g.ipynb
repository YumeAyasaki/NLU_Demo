# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from tqdm import tqdm
import ipywidgets as widgets
from ipywidgets import interact, interact_manual, interactive
from IPython.display import display


from utils.metric import roc_auc
from utils.model import define_rnn_model, define_cnn_model, define_lstm_model, define_gru_model, define_bi_model, define_cnn_rnn_model

if not tf.__version__.startswith('2'):
    raise ValueError('This code requires TensorFlow V2.x')

# %%
# Data
o_train = pd.read_csv('Data/jigsaw-toxic-comment-train.csv')

# Pre processing
o_train.drop(['severe_toxic','obscene','threat','insult','identity_hate'],axis=1,inplace=True) # Drop other columns

# Get input
type_input = widgets.Dropdown(
    options=['Phần trăm', 'Số lượng'],
    value='Số lượng',
    description='Dữ liệu vào',
    disabled=False,
)
value_input = widgets.IntSlider(
    value=50000,
    min=0,
    max=o_train.shape[0],
    step=1000,
    description='Số lượng',
    readout=True
)

def update_value_input(*args):
    if type_input.value == 'Số lượng':
        value_input.value=50000
        value_input.max=o_train.shape[0]
        value_input.step=1000
        value_input.description='Số lượng'
    else:
        value_input.value=50
        value_input.max=100
        value_input.step=1
        value_input.description='Phần trăm'
type_input.observe(update_value_input, 'value')

display(type_input)
display(value_input)
# Out:
# Dropdown(description='Dữ liệu vào', index=1, options=('Phần trăm', 'Số lượng'), value='Số lượng')
# IntSlider(value=50000, description='Số lượng', max=223549, step=1000)

# %%
model_array = ['cnn', 'lstm', 'gru', 'bi_directional', 'cnn + rnn']

model_input = widgets.Dropdown(
    options=model_array,
    value='cnn',
    description='Loại mô hình',
    disabled=False,
)

display(model_input)
# Out:
# Dropdown(description='Loại mô hình', options=('cnn', 'lstm', 'gru', 'bi_directional', 'cnn + rnn'), value='cnn…

# %%
# # Embedding
# embeddings_index = {}
# f = open('glove.840B.300d.txt','r',encoding='utf-8')
# for line in tqdm(f):
#     values = line.split(' ')
#     word = values[0]
#     coefs = np.asarray([float(val) for val in values[1:]])
#     embeddings_index[word] = coefs
# f.close()

# print('Found %s word vectors.' % len(embeddings_index))

# %%
if type_input.value == 'Số lượng':
    train = o_train.loc[:value_input.value,:]
else:
    train = o_train.loc[:value_input.value * o_train.shape[0] / 100,:]
max_test = train['comment_text'].apply(lambda x:len(str(x).split())).max() # Max test's length

xtrain, xvalid, ytrain, yvalid = train_test_split(train.comment_text.values, train.toxic.values,
                                                  stratify=train.toxic.values,
                                                  random_state=42,
                                                  test_size=0.2, shuffle=True)

# %%
token = keras.preprocessing.text.Tokenizer(num_words=None)

token.fit_on_texts(list(xtrain) + list(xvalid))
xtrain_seq = token.texts_to_sequences(xtrain)
xvalid_seq = token.texts_to_sequences(xvalid)

#zero pad the sequences
xtrain_pad = keras.preprocessing.sequence.pad_sequences(xtrain_seq, maxlen=max_test)
xvalid_pad = keras.preprocessing.sequence.pad_sequences(xvalid_seq, maxlen=max_test)

word_index = token.word_index

# %%
max_vocab = len(word_index) + 1
model_type_array = {
    'lstm': define_lstm_model(max_vocab, max_test),
    'cnn': define_cnn_model(max_vocab, max_test),
    'gru': define_gru_model(max_vocab, max_test),
    'bi_directional': define_bi_model(max_vocab, max_test),
    'cnn + rnn': define_cnn_rnn_model(max_vocab, max_test),
}
with open('results.txt', 'w') as writefile:
    # writefile.write("This is line A")
    for model_m in model_array:
        model = model_type_array[model_m]
        print(model_m)
        if model_m == 'cnn':
            history = model.fit([xtrain_pad, xtrain_pad, xtrain_pad], ytrain, epochs=10)
            model.save('cnn.keras')
            scores = model.predict([xvalid_pad, xvalid_pad, xvalid_pad])
            print("Auc: %.2f%%" % (roc_auc(scores, yvalid)))
            writefile.write(model_m + " Auc: %.2f%%" % (roc_auc(scores, yvalid)))
        else:
            history = model.fit(xtrain_pad, ytrain, epochs=10)
            model.save(model_input.value + '.keras')
            scores = model.predict(xvalid_pad)
            print("Auc: %.2f%%" % (roc_auc(scores, yvalid)))
            writefile.write(model_m + " Auc: %.2f%%" % (roc_auc(scores, yvalid)))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1403, 100)         10255400
#
#  lstm (LSTM)                 (None, 100)               80400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 10,335,901
# Trainable params: 10,335,901
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1403)]       0           []
#
#  input_2 (InputLayer)           [(None, 1403)]       0           []
#
#  input_3 (InputLayer)           [(None, 1403)]       0           []
#
#  embedding_1 (Embedding)        (None, 1403, 100)    10255400    ['input_1[0][0]']
#
#  embedding_2 (Embedding)        (None, 1403, 100)    10255400    ['input_2[0][0]']
#
#  embedding_3 (Embedding)        (None, 1403, 100)    10255400    ['input_3[0][0]']
#
#  conv1d (Conv1D)                (None, 1400, 32)     12832       ['embedding_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 1398, 32)     19232       ['embedding_2[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1396, 32)     25632       ['embedding_3[0][0]']
#
#  dropout (Dropout)              (None, 1400, 32)     0           ['conv1d[0][0]']
#
#  dropout_1 (Dropout)            (None, 1398, 32)     0           ['conv1d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 1396, 32)     0           ['conv1d_2[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 700, 32)      0           ['dropout[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 699, 32)     0           ['dropout_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 698, 32)     0           ['dropout_2[0][0]']
#
#  flatten (Flatten)              (None, 22400)        0           ['max_pooling1d[0][0]']
#
#  flatten_1 (Flatten)            (None, 22368)        0           ['max_pooling1d_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 22336)        0           ['max_pooling1d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 67104)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]',
#                                                                   'flatten_2[0][0]']
#
#  dense_1 (Dense)                (None, 10)           671050      ['concatenate[0][0]']
#
#  dense_2 (Dense)                (None, 1)            11          ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 31,494,957
# Trainable params: 31,494,957
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 1403, 100)         10255400
#
#  spatial_dropout1d (SpatialD  (None, 1403, 100)        0
#  ropout1D)
#
#  gru (GRU)                   (None, 100)               60600
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 10,316,101
# Trainable params: 10,316,101
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 1403, 100)         10255400
#
#  bidirectional (Bidirectiona  (None, 200)              160800
#  l)
#
#  dense_4 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 10,416,401
# Trainable params: 10,416,401
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 1403, 100)         10255400
#
#  conv1d_3 (Conv1D)           (None, 1397, 32)          22432
#
#  max_pooling1d_3 (MaxPooling  (None, 279, 32)          0
#  1D)
#
#  bidirectional_1 (Bidirectio  (None, 279, 200)         106400
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dense_5 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 10,625,233
# Trainable params: 10,625,233
# Non-trainable params: 0
# _________________________________________________________________
# cnn
# Epoch 1/10
# 1250/1250 [==============================] - 101s 77ms/step - loss: 0.1967 - accuracy: 0.9333
# Epoch 2/10
# 1250/1250 [==============================] - 100s 80ms/step - loss: 0.0916 - accuracy: 0.9722
# Epoch 3/10
# 1250/1250 [==============================] - 102s 82ms/step - loss: 0.0495 - accuracy: 0.9871
# Epoch 4/10
# 1250/1250 [==============================] - 101s 81ms/step - loss: 0.0319 - accuracy: 0.9926
# Epoch 5/10
# 1250/1250 [==============================] - 102s 81ms/step - loss: 0.0234 - accuracy: 0.9944
# Epoch 6/10
# 1250/1250 [==============================] - 102s 82ms/step - loss: 0.0193 - accuracy: 0.9956
# Epoch 7/10
# 1250/1250 [==============================] - 102s 82ms/step - loss: 0.0161 - accuracy: 0.9962
# Epoch 8/10
# 1250/1250 [==============================] - 102s 81ms/step - loss: 0.0132 - accuracy: 0.9970
# Epoch 9/10
# 1250/1250 [==============================] - 103s 82ms/step - loss: 0.0131 - accuracy: 0.9969
# Epoch 10/10
# 1250/1250 [==============================] - 102s 82ms/step - loss: 0.0135 - accuracy: 0.9969
# 313/313 [==============================] - 4s 13ms/step
# Auc: 0.93%
# lstm
# Epoch 1/10
# 1250/1250 [==============================] - 163s 123ms/step - loss: 0.1851 - accuracy: 0.9375
# Epoch 2/10
# 1250/1250 [==============================] - 154s 123ms/step - loss: 0.0997 - accuracy: 0.9653
# Epoch 3/10
# 1250/1250 [==============================] - 156s 125ms/step - loss: 0.0629 - accuracy: 0.9776
# Epoch 4/10
# 1250/1250 [==============================] - 155s 124ms/step - loss: 0.0390 - accuracy: 0.9867
# Epoch 5/10
# 1250/1250 [==============================] - 154s 123ms/step - loss: 0.0247 - accuracy: 0.9917
# Epoch 6/10
# 1250/1250 [==============================] - 154s 123ms/step - loss: 0.0164 - accuracy: 0.9947
# Epoch 7/10
# 1250/1250 [==============================] - 155s 124ms/step - loss: 0.0121 - accuracy: 0.9961
# Epoch 8/10
# 1250/1250 [==============================] - 155s 124ms/step - loss: 0.0072 - accuracy: 0.9977
# Epoch 9/10
# 1250/1250 [==============================] - 154s 123ms/step - loss: 0.0053 - accuracy: 0.9980
# Epoch 10/10
# 1250/1250 [==============================] - 155s 124ms/step - loss: 0.0038 - accuracy: 0.9986
# 313/313 [==============================] - 14s 42ms/step
# Auc: 0.94%
# gru
# Epoch 1/10
# 1250/1250 [==============================] - 152s 120ms/step - loss: 0.1650 - accuracy: 0.9446
# Epoch 2/10
# 1250/1250 [==============================] - 149s 120ms/step - loss: 0.0758 - accuracy: 0.9717
# Epoch 3/10
# 1250/1250 [==============================] - 149s 119ms/step - loss: 0.0448 - accuracy: 0.9837
# Epoch 4/10
# 1250/1250 [==============================] - 149s 119ms/step - loss: 0.0259 - accuracy: 0.9910
# Epoch 5/10
# 1250/1250 [==============================] - 150s 120ms/step - loss: 0.0132 - accuracy: 0.9954
# Epoch 6/10
# 1250/1250 [==============================] - 148s 118ms/step - loss: 0.0076 - accuracy: 0.9977
# Epoch 7/10
# 1250/1250 [==============================] - 149s 119ms/step - loss: 0.0055 - accuracy: 0.9984
# Epoch 8/10
# 1250/1250 [==============================] - 150s 120ms/step - loss: 0.0051 - accuracy: 0.9982
# Epoch 9/10
# 1250/1250 [==============================] - 148s 119ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 10/10
# 1250/1250 [==============================] - 148s 118ms/step - loss: 0.0023 - accuracy: 0.9993
# 313/313 [==============================] - 14s 41ms/step
# Auc: 0.94%
# bi_directional
# Epoch 1/10
# 1250/1250 [==============================] - 273s 214ms/step - loss: 0.1790 - accuracy: 0.9391
# Epoch 2/10
# 1250/1250 [==============================] - 267s 214ms/step - loss: 0.0924 - accuracy: 0.9671
# Epoch 3/10
# 1250/1250 [==============================] - 272s 217ms/step - loss: 0.0556 - accuracy: 0.9802
# Epoch 4/10
# 1250/1250 [==============================] - 269s 215ms/step - loss: 0.0329 - accuracy: 0.9888
# Epoch 5/10
# 1250/1250 [==============================] - 269s 215ms/step - loss: 0.0205 - accuracy: 0.9934
# Epoch 6/10
# 1250/1250 [==============================] - 269s 215ms/step - loss: 0.0141 - accuracy: 0.9955
# Epoch 7/10
# 1250/1250 [==============================] - 268s 214ms/step - loss: 0.0096 - accuracy: 0.9966
# Epoch 8/10
# 1250/1250 [==============================] - 270s 216ms/step - loss: 0.0079 - accuracy: 0.9973
# Epoch 9/10
# 1250/1250 [==============================] - 269s 215ms/step - loss: 0.0047 - accuracy: 0.9983
# Epoch 10/10
# 1250/1250 [==============================] - 270s 216ms/step - loss: 0.0043 - accuracy: 0.9986
# 313/313 [==============================] - 26s 79ms/step
# Auc: 0.93%
# cnn + rnn
# Epoch 1/10
# 1250/1250 [==============================] - 172s 130ms/step - loss: 0.1905 - accuracy: 0.9332
# Epoch 2/10
# 1250/1250 [==============================] - 164s 131ms/step - loss: 0.0978 - accuracy: 0.9641
# Epoch 3/10
# 1250/1250 [==============================] - 164s 131ms/step - loss: 0.0500 - accuracy: 0.9819
# Epoch 4/10
# 1250/1250 [==============================] - 165s 132ms/step - loss: 0.0257 - accuracy: 0.9914
# Epoch 5/10
# 1250/1250 [==============================] - 164s 131ms/step - loss: 0.0167 - accuracy: 0.9943
# Epoch 6/10
# 1250/1250 [==============================] - 163s 131ms/step - loss: 0.0141 - accuracy: 0.9955
# Epoch 7/10
# 1250/1250 [==============================] - 166s 132ms/step - loss: 0.0154 - accuracy: 0.9947
# Epoch 8/10
# 1250/1250 [==============================] - 165s 132ms/step - loss: 0.0094 - accuracy: 0.9969
# Epoch 9/10
# 1250/1250 [==============================] - 165s 132ms/step - loss: 0.0091 - accuracy: 0.9971
# Epoch 10/10
# 1250/1250 [==============================] - 164s 131ms/step - loss: 0.0073 - accuracy: 0.9977
# 313/313 [==============================] - 16s 44ms/step
# Auc: 0.92%
